# %% [markdown]
# # Plant Disease Dataset EDA
# Runs dataset statistics from the production preprocessing module.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from preprocessing.dataset_stats import generate_dataset_statistics
stats = generate_dataset_statistics()
stats
