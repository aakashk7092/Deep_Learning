# %% [markdown]
# # Model Training
# Trains the production EfficientNetB0 model using the shared training pipeline.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from training.train import train_model
model = train_model(architecture='efficientnetb0')
model.name
